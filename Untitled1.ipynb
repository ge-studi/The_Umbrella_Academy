# %% [markdown]
# **Web Scraping and Sentiment Analyzer for The Umbrella Academy**

# %% [markdown]
# **Web Scraping**

# %%
import requests
from bs4 import BeautifulSoup

# Specify the URL of the website
url = 'https://en.wikipedia.org/wiki/The_Umbrella_Academy_(TV_series)'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'lxml')  # Use 'lxml' or 'html5lib' as per your preference

    #Extracting paragraph
    paragraphs = soup.find_all('p')
    for paragraph in paragraphs:
        print(paragraph.text)
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# The Umbrella Academy is an American superhero comedy-drama television series based on the comic book series of the same name written by Gerard Way, illustrated by Gabriel Bá, and published by Dark Horse Comics. Created for Netflix by Steve Blackman and developed by Jeremy Slater, it revolves around a dysfunctional family of adopted sibling superheroes who reunite for their father's funeral and the threat of an imminent apocalypse. The series is produced by Borderline Entertainment (season 1–2), Irish Cowboy (season 3), Dark Horse Entertainment, and Universal Content Productions. Netflix gave seasons 1 and 2 a TV-14 rating, while seasons 3 and 4 received a TV-MA rating.
#
# ...

# %%
import nltk

# Download the nltk punkt data for sentence tokenization
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
sentences = []
for paragraph in paragraphs:
 sentences.extend(nltk.sent_tokenize(paragraph.text))

# %%
import re

# %%
cleaned_sentences = [re.sub(r'\[.*?\]', '', sentence) for sentence in sentences]

# %%
import pandas as pd
import numpy as np

# %%
#Create a DataFrame
data = {'Sentences': cleaned_sentences}
df = pd.DataFrame(data)

# Save DataFrame to a CSV file
df.to_csv('sentences.csv', index=False)

# %%
df.head(10)
# Out:
#                                            Sentences
# 0  The Umbrella Academy is an American superhero ...
# 1  Created for Netflix by Steve Blackman and deve...
# 2  The series is produced by Borderline Entertain...
# 3  Netflix gave seasons 1 and 2 a TV-14 rating, w...
# 4  The cast features Elliot Page, Tom Hopper, Dav...
# 5  The adaptation began development as a film opt...
# 6  It was eventually shelved in favor of a televi...
# 7  The series was filmed in Toronto and Hamilton,...
# 8  The first season was released on Netflix on Fe...
# 9  In April 2019, Netflix reported that 45 millio...

# %%
df.isnull().sum()
# Out:
# Sentences    0
# dtype: int64

# %%
#Remove null values
cleaned_df = df.dropna(subset=df.columns, how='all')

# %%
cleaned_df.isnull().sum()
# Out:
# Sentences    0
# dtype: int64

# %%
cleaned_df.head(10)
# Out:
#                                            Sentences
# 0  The Umbrella Academy is an American superhero ...
# 1  Created for Netflix by Steve Blackman and deve...
# 2  The series is produced by Borderline Entertain...
# 3  Netflix gave seasons 1 and 2 a TV-14 rating, w...
# 4  The cast features Elliot Page, Tom Hopper, Dav...
# 5  The adaptation began development as a film opt...
# 6  It was eventually shelved in favor of a televi...
# 7  The series was filmed in Toronto and Hamilton,...
# 8  The first season was released on Netflix on Fe...
# 9  In April 2019, Netflix reported that 45 millio...
# No charts were generated by quickchart

# %% [markdown]
# **Sentiment Analysis**

# %%
umbrella_academy = pd.read_excel('umbrella_academy_reviews.xlsx')

# %%
umbrella_academy.head(10)
# Out:
#                                               review
# 0  The Umbrella Academy is an American superhero ...
# 1  The series explores themes of time travel, fam...
# 2  Critical reception for the show has been gener...

# %%
nltk.download('vader_lexicon')
from nltk.sentiment import SentimentIntensityAnalyzer

# Assuming 'umbrella_academy' is your DataFrame
umbrella_academy['review'] = umbrella_academy['review'].fillna('')  # Replace NaN with an empty string

# Initialize the Sentiment Intensity Analyzer
sia = SentimentIntensityAnalyzer()

# Create a new column 'Sentiment' with sentiment scores
umbrella_academy['Sentiment'] = umbrella_academy['review'].apply(lambda x: sia.polarity_scores(x)['compound'])
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
threshold_angry = -0.7
threshold_anguish = -0.5
threshold_contempt = -0.05
threshold_worry = 0
threshold_ambiguity = 0.1
threshold_affection = 0.2
threshold_sacrifice = 0.3
threshold_protectiveness = 0.5
threshold_sarcasm = 0.6

# Create conditions and corresponding labels
conditions = [
    umbrella_academy['Sentiment'] <= threshold_angry,
    (umbrella_academy['Sentiment'] > threshold_angry) & (umbrella_academy['Sentiment'] <= threshold_anguish),
    (umbrella_academy['Sentiment'] > threshold_anguish) & (umbrella_academy['Sentiment'] <= threshold_contempt),
    (umbrella_academy['Sentiment'] > threshold_contempt) & (umbrella_academy['Sentiment'] <= threshold_worry),
    (umbrella_academy['Sentiment'] > threshold_worry) & (umbrella_academy['Sentiment'] <= threshold_ambiguity),
    (umbrella_academy['Sentiment'] > threshold_ambiguity) & (umbrella_academy['Sentiment'] <= threshold_affection),
    (umbrella_academy['Sentiment'] > threshold_affection) & (umbrella_academy['Sentiment'] <= threshold_sacrifice),
    (umbrella_academy['Sentiment'] > threshold_sacrifice) & (umbrella_academy['Sentiment'] <= threshold_protectiveness),
    (umbrella_academy['Sentiment'] > threshold_protectiveness) & (umbrella_academy['Sentiment'] <= threshold_sarcasm),
    umbrella_academy['Sentiment'] > threshold_sarcasm
]

labels = ['angry', 'anguish', 'contempt', 'worry','ambiguity', 'affection', 'sacrifice', 'protectiveness', 'sarcasm', 'unknown']

# Create a new column with the sentiment categories
umbrella_academy['Emotion_Category'] = np.select(conditions, labels, default='unknown')

# %%
emotion_percentages = umbrella_academy['Emotion_Category'].value_counts(normalize=True) * 100
emotion_percentages
# Out:
# Emotion_Category
# angry      33.333333
# anguish    33.333333
# unknown    33.333333
# Name: proportion, dtype: float64

# %%
from nltk import FreqDist
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
all_text = ' '.join(umbrella_academy['review'].astype(str))

# Tokenize the text into words
words = word_tokenize(all_text)

# Remove stop words and punctuation
stop_words = set(stopwords.words('english'))
filtered_words = [word.lower() for word in words if word.isalnum() and word.lower() not in stop_words]

# Lemmatize the words
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]

# Calculate the frequency distribution of words
freq_dist = FreqDist(lemmatized_words)

# Find the top 5 most common words
top_words = freq_dist.most_common(5)

# Print the top 5 most common words and their frequencies
for word, frequency in top_words:
    print(f"The word '{word}' appears {frequency} times.")
# Out:
# The word 'series' appears 3 times.
# The word 'superhero' appears 2 times.
# The word 'family' appears 2 times.
# The word 'page' appears 2 times.
# The word 'umbrella' appears 1 times.

# %%
umbrella_academy .to_csv('umbrella_academy_dataset.csv')
